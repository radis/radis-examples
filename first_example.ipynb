# %% [markdown]
# # First Example
#
# Run the [Quick Start](https://radis.readthedocs.io/en/latest/#quick-start) example from the [https://radis.readthedocs.io](RADIS documentation)
#
# ---

# %%
from radis import calc_spectrum
s = calc_spectrum(1900, 2300,         # cm-1
                  molecule='CO',
                  isotope='1,2,3',
                  pressure=1.01325,   # bar
                  Tgas=1000,          # K
                  mole_fraction=0.1,
                  path_length=1,      # cm
                  )
s.apply_slit(0.5, 'nm')
s.plot('radiance')

# %% [markdown]
# See the [RADIS Documentation: Spectrum how to?](radis.readthedocs.io/en/latest/spectrum/howto.html) for more post-processing methods
#
# Now calculate a nonequilibrium spectrum:

# %%
s2 = calc_spectrum(1900, 2300,         # cm-1
                  molecule='CO',
                  isotope='1,2,3',
                  pressure=1.01325,   # bar
                  Tvib=1000,          # K
                  Trot=300,           # K
                  mole_fraction=0.1,
                  path_length=1,      # cm
                  )
s2.apply_slit(0.5, 'nm')
s2.plot('radiance', nfig='same')    # compare with previous

# %% [markdown]
# Now calculate your own spectra:
